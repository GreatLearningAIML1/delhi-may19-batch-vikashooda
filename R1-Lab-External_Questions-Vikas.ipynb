# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd
import os

# %%
iris_list=pd.read_csv('iris.csv')
iris_list
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd 
iris=pd.DataFrame(data=iris_list)
iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
print(iris.dtypes)
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
print(iris.head(10))
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
print(iris.tail(10))
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
print(iris.shape)
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris.set_index('Class')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-3b0b122567b3> in <module>
# ----> 1 iris.set_index('Class')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4176                 names.append(None)
#    4177             else:
# -> 4178                 level = frame[col]._values
#    4179                 names.append(col)
#    4180                 if drop:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.iloc[2]
# Out:
# Sepal Length (in cm)    4.7
# Sepal Width in (cm)     3.2
# Petal length (in cm)    1.3
# Petal width (in cm)     0.2
# Name: Iris-setosa, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.iloc[:,0:2]
# Out:
#                 Sepal Length (in cm)  Sepal Width in (cm)
# Class
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      4.9                  3.0
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      4.6                  3.1
# Iris-setosa                      5.0                  3.6
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      4.6                  3.4
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      4.4                  2.9
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      5.4                  3.7
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      4.8                  3.0
# Iris-setosa                      4.3                  3.0
# Iris-setosa                      5.8                  4.0
# Iris-setosa                      5.7                  4.4
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      5.7                  3.8
# Iris-setosa                      5.1                  3.8
# Iris-setosa                      5.4                  3.4
# Iris-setosa                      5.1                  3.7
# Iris-setosa                      4.6                  3.6
# Iris-setosa                      5.1                  3.3
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      5.0                  3.0
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      5.2                  3.5
# Iris-setosa                      5.2                  3.4
# Iris-setosa                      4.7                  3.2
# ...                              ...                  ...
# Iris-virginica                   6.9                  3.2
# Iris-virginica                   5.6                  2.8
# Iris-virginica                   7.7                  2.8
# Iris-virginica                   6.3                  2.7
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   7.2                  3.2
# Iris-virginica                   6.2                  2.8
# Iris-virginica                   6.1                  3.0
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   7.2                  3.0
# Iris-virginica                   7.4                  2.8
# Iris-virginica                   7.9                  3.8
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   6.3                  2.8
# Iris-virginica                   6.1                  2.6
# Iris-virginica                   7.7                  3.0
# Iris-virginica                   6.3                  3.4
# Iris-virginica                   6.4                  3.1
# Iris-virginica                   6.0                  3.0
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   6.7                  3.1
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   5.8                  2.7
# Iris-virginica                   6.8                  3.2
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   6.7                  3.0
# Iris-virginica                   6.3                  2.5
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   6.2                  3.4
# Iris-virginica                   5.9                  3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
if iris['Class'] == ("Iris-setosa")[iris]
# Out:
#   File "<ipython-input-56-bea10051e3b8>", line 1
#     if iris['Class'] == ("Iris-setosa")[iris]
#                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris
# Out:
#                 Sepal Length (in cm)  Sepal Width in (cm)  \
# Class
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      4.9                  3.0
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      4.6                  3.1
# Iris-setosa                      5.0                  3.6
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      4.6                  3.4
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      4.4                  2.9
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      5.4                  3.7
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      4.8                  3.0
# Iris-setosa                      4.3                  3.0
# Iris-setosa                      5.8                  4.0
# Iris-setosa                      5.7                  4.4
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      5.7                  3.8
# Iris-setosa                      5.1                  3.8
# Iris-setosa                      5.4                  3.4
# Iris-setosa                      5.1                  3.7
# Iris-setosa                      4.6                  3.6
# Iris-setosa                      5.1                  3.3
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      5.0                  3.0
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      5.2                  3.5
# Iris-setosa                      5.2                  3.4
# Iris-setosa                      4.7                  3.2
# ...                              ...                  ...
# Iris-virginica                   6.9                  3.2
# Iris-virginica                   5.6                  2.8
# Iris-virginica                   7.7                  2.8
# Iris-virginica                   6.3                  2.7
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   7.2                  3.2
# Iris-virginica                   6.2                  2.8
# Iris-virginica                   6.1                  3.0
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   7.2                  3.0
# Iris-virginica                   7.4                  2.8
# Iris-virginica                   7.9                  3.8
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   6.3                  2.8
# Iris-virginica                   6.1                  2.6
# Iris-virginica                   7.7                  3.0
# Iris-virginica                   6.3                  3.4
# Iris-virginica                   6.4                  3.1
# Iris-virginica                   6.0                  3.0
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   6.7                  3.1
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   5.8                  2.7
# Iris-virginica                   6.8                  3.2
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   6.7                  3.0
# Iris-virginica                   6.3                  2.5
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   6.2                  3.4
# Iris-virginica                   5.9                  3.0
#
#                 Petal length (in cm)  Petal width (in cm)
# Class
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.3                  0.2
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.7                  0.4
# Iris-setosa                      1.4                  0.3
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.5                  0.1
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.6                  0.2
# Iris-setosa                      1.4                  0.1
# Iris-setosa                      1.1                  0.1
# Iris-setosa                      1.2                  0.2
# Iris-setosa                      1.5                  0.4
# Iris-setosa                      1.3                  0.4
# Iris-setosa                      1.4                  0.3
# Iris-setosa                      1.7                  0.3
# Iris-setosa                      1.5                  0.3
# Iris-setosa                      1.7                  0.2
# Iris-setosa                      1.5                  0.4
# Iris-setosa                      1.0                  0.2
# Iris-setosa                      1.7                  0.5
# Iris-setosa                      1.9                  0.2
# Iris-setosa                      1.6                  0.2
# Iris-setosa                      1.6                  0.4
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.6                  0.2
# ...                              ...                  ...
# Iris-virginica                   5.7                  2.3
# Iris-virginica                   4.9                  2.0
# Iris-virginica                   6.7                  2.0
# Iris-virginica                   4.9                  1.8
# Iris-virginica                   5.7                  2.1
# Iris-virginica                   6.0                  1.8
# Iris-virginica                   4.8                  1.8
# Iris-virginica                   4.9                  1.8
# Iris-virginica                   5.6                  2.1
# Iris-virginica                   5.8                  1.6
# Iris-virginica                   6.1                  1.9
# Iris-virginica                   6.4                  2.0
# Iris-virginica                   5.6                  2.2
# Iris-virginica                   5.1                  1.5
# Iris-virginica                   5.6                  1.4
# Iris-virginica                   6.1                  2.3
# Iris-virginica                   5.6                  2.4
# Iris-virginica                   5.5                  1.8
# Iris-virginica                   4.8                  1.8
# Iris-virginica                   5.4                  2.1
# Iris-virginica                   5.6                  2.4
# Iris-virginica                   5.1                  2.3
# Iris-virginica                   5.1                  1.9
# Iris-virginica                   5.9                  2.3
# Iris-virginica                   5.7                  2.5
# Iris-virginica                   5.2                  2.3
# Iris-virginica                   5.0                  1.9
# Iris-virginica                   5.2                  2.0
# Iris-virginica                   5.4                  2.3
# Iris-virginica                   5.1                  1.8
#
# [150 rows x 4 columns]

# %%
import pandas as pd
iris['SepalExtra']= iris['Sepal Length']*iris.['Sepal Width']
# Out:
#   File "<ipython-input-83-802bb8feba4c>", line 2
#     iris['SepalExtra']= iris['Sepal Length']*iris.['Sepal Width']
#                                                   ^
# SyntaxError: invalid syntax

# %%
iris
# Out:
#                 Sepal Length (in cm)  Sepal Width in (cm)  \
# Class
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      4.9                  3.0
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      4.6                  3.1
# Iris-setosa                      5.0                  3.6
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      4.6                  3.4
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      4.4                  2.9
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      5.4                  3.7
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      4.8                  3.0
# Iris-setosa                      4.3                  3.0
# Iris-setosa                      5.8                  4.0
# Iris-setosa                      5.7                  4.4
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      5.7                  3.8
# Iris-setosa                      5.1                  3.8
# Iris-setosa                      5.4                  3.4
# Iris-setosa                      5.1                  3.7
# Iris-setosa                      4.6                  3.6
# Iris-setosa                      5.1                  3.3
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      5.0                  3.0
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      5.2                  3.5
# Iris-setosa                      5.2                  3.4
# Iris-setosa                      4.7                  3.2
# ...                              ...                  ...
# Iris-virginica                   6.9                  3.2
# Iris-virginica                   5.6                  2.8
# Iris-virginica                   7.7                  2.8
# Iris-virginica                   6.3                  2.7
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   7.2                  3.2
# Iris-virginica                   6.2                  2.8
# Iris-virginica                   6.1                  3.0
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   7.2                  3.0
# Iris-virginica                   7.4                  2.8
# Iris-virginica                   7.9                  3.8
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   6.3                  2.8
# Iris-virginica                   6.1                  2.6
# Iris-virginica                   7.7                  3.0
# Iris-virginica                   6.3                  3.4
# Iris-virginica                   6.4                  3.1
# Iris-virginica                   6.0                  3.0
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   6.7                  3.1
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   5.8                  2.7
# Iris-virginica                   6.8                  3.2
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   6.7                  3.0
# Iris-virginica                   6.3                  2.5
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   6.2                  3.4
# Iris-virginica                   5.9                  3.0
#
#                 Petal length (in cm)  Petal width (in cm)
# Class
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.3                  0.2
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.7                  0.4
# Iris-setosa                      1.4                  0.3
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.5                  0.1
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.6                  0.2
# Iris-setosa                      1.4                  0.1
# Iris-setosa                      1.1                  0.1
# Iris-setosa                      1.2                  0.2
# Iris-setosa                      1.5                  0.4
# Iris-setosa                      1.3                  0.4
# Iris-setosa                      1.4                  0.3
# Iris-setosa                      1.7                  0.3
# Iris-setosa                      1.5                  0.3
# Iris-setosa                      1.7                  0.2
# Iris-setosa                      1.5                  0.4
# Iris-setosa                      1.0                  0.2
# Iris-setosa                      1.7                  0.5
# Iris-setosa                      1.9                  0.2
# Iris-setosa                      1.6                  0.2
# Iris-setosa                      1.6                  0.4
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.6                  0.2
# ...                              ...                  ...
# Iris-virginica                   5.7                  2.3
# Iris-virginica                   4.9                  2.0
# Iris-virginica                   6.7                  2.0
# Iris-virginica                   4.9                  1.8
# Iris-virginica                   5.7                  2.1
# Iris-virginica                   6.0                  1.8
# Iris-virginica                   4.8                  1.8
# Iris-virginica                   4.9                  1.8
# Iris-virginica                   5.6                  2.1
# Iris-virginica                   5.8                  1.6
# Iris-virginica                   6.1                  1.9
# Iris-virginica                   6.4                  2.0
# Iris-virginica                   5.6                  2.2
# Iris-virginica                   5.1                  1.5
# Iris-virginica                   5.6                  1.4
# Iris-virginica                   6.1                  2.3
# Iris-virginica                   5.6                  2.4
# Iris-virginica                   5.5                  1.8
# Iris-virginica                   4.8                  1.8
# Iris-virginica                   5.4                  2.1
# Iris-virginica                   5.6                  2.4
# Iris-virginica                   5.1                  2.3
# Iris-virginica                   5.1                  1.9
# Iris-virginica                   5.9                  2.3
# Iris-virginica                   5.7                  2.5
# Iris-virginica                   5.2                  2.3
# Iris-virginica                   5.0                  1.9
# Iris-virginica                   5.2                  2.0
# Iris-virginica                   5.4                  2.3
# Iris-virginica                   5.1                  1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.mean()
# Out:
# Sepal Length (in cm)    5.843333
# Sepal Width in (cm)     3.054000
# Petal length (in cm)    3.758667
# Petal width (in cm)     1.198667
# dtype: float64

# %%
iris.var()
# Out:
# Sepal Length (in cm)    0.685694
# Sepal Width in (cm)     0.188004
# Petal length (in cm)    3.113179
# Petal width (in cm)     0.582414
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
Series=pd.Series(data=[1,2], index=['Sepal Length','Sepal Width'])
Series
# Out:
# Sepal Length    1
# Sepal Width     2
# dtype: int64

# %%
iris=iris[Index=(4,:)]+Series

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
iris.max()-iris.min()
# Out:
# Sepal Length (in cm)    3.6
# Sepal Width in (cm)     2.4
# Petal length (in cm)    5.9
# Petal width (in cm)     2.4
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_index(axis=1,level='Petal Width')
# Out:
#                 Petal length (in cm)  Petal width (in cm)  \
# Class
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.3                  0.2
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.7                  0.4
# Iris-setosa                      1.4                  0.3
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.5                  0.1
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.6                  0.2
# Iris-setosa                      1.4                  0.1
# Iris-setosa                      1.1                  0.1
# Iris-setosa                      1.2                  0.2
# Iris-setosa                      1.5                  0.4
# Iris-setosa                      1.3                  0.4
# Iris-setosa                      1.4                  0.3
# Iris-setosa                      1.7                  0.3
# Iris-setosa                      1.5                  0.3
# Iris-setosa                      1.7                  0.2
# Iris-setosa                      1.5                  0.4
# Iris-setosa                      1.0                  0.2
# Iris-setosa                      1.7                  0.5
# Iris-setosa                      1.9                  0.2
# Iris-setosa                      1.6                  0.2
# Iris-setosa                      1.6                  0.4
# Iris-setosa                      1.5                  0.2
# Iris-setosa                      1.4                  0.2
# Iris-setosa                      1.6                  0.2
# ...                              ...                  ...
# Iris-virginica                   5.7                  2.3
# Iris-virginica                   4.9                  2.0
# Iris-virginica                   6.7                  2.0
# Iris-virginica                   4.9                  1.8
# Iris-virginica                   5.7                  2.1
# Iris-virginica                   6.0                  1.8
# Iris-virginica                   4.8                  1.8
# Iris-virginica                   4.9                  1.8
# Iris-virginica                   5.6                  2.1
# Iris-virginica                   5.8                  1.6
# Iris-virginica                   6.1                  1.9
# Iris-virginica                   6.4                  2.0
# Iris-virginica                   5.6                  2.2
# Iris-virginica                   5.1                  1.5
# Iris-virginica                   5.6                  1.4
# Iris-virginica                   6.1                  2.3
# Iris-virginica                   5.6                  2.4
# Iris-virginica                   5.5                  1.8
# Iris-virginica                   4.8                  1.8
# Iris-virginica                   5.4                  2.1
# Iris-virginica                   5.6                  2.4
# Iris-virginica                   5.1                  2.3
# Iris-virginica                   5.1                  1.9
# Iris-virginica                   5.9                  2.3
# Iris-virginica                   5.7                  2.5
# Iris-virginica                   5.2                  2.3
# Iris-virginica                   5.0                  1.9
# Iris-virginica                   5.2                  2.0
# Iris-virginica                   5.4                  2.3
# Iris-virginica                   5.1                  1.8
#
#                 Sepal Length (in cm)  Sepal Width in (cm)
# Class
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      4.9                  3.0
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      4.6                  3.1
# Iris-setosa                      5.0                  3.6
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      4.6                  3.4
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      4.4                  2.9
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      5.4                  3.7
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      4.8                  3.0
# Iris-setosa                      4.3                  3.0
# Iris-setosa                      5.8                  4.0
# Iris-setosa                      5.7                  4.4
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      5.7                  3.8
# Iris-setosa                      5.1                  3.8
# Iris-setosa                      5.4                  3.4
# Iris-setosa                      5.1                  3.7
# Iris-setosa                      4.6                  3.6
# Iris-setosa                      5.1                  3.3
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      5.0                  3.0
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      5.2                  3.5
# Iris-setosa                      5.2                  3.4
# Iris-setosa                      4.7                  3.2
# ...                              ...                  ...
# Iris-virginica                   6.9                  3.2
# Iris-virginica                   5.6                  2.8
# Iris-virginica                   7.7                  2.8
# Iris-virginica                   6.3                  2.7
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   7.2                  3.2
# Iris-virginica                   6.2                  2.8
# Iris-virginica                   6.1                  3.0
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   7.2                  3.0
# Iris-virginica                   7.4                  2.8
# Iris-virginica                   7.9                  3.8
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   6.3                  2.8
# Iris-virginica                   6.1                  2.6
# Iris-virginica                   7.7                  3.0
# Iris-virginica                   6.3                  3.4
# Iris-virginica                   6.4                  3.1
# Iris-virginica                   6.0                  3.0
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   6.7                  3.1
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   5.8                  2.7
# Iris-virginica                   6.8                  3.2
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   6.7                  3.0
# Iris-virginica                   6.3                  2.5
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   6.2                  3.4
# Iris-virginica                   5.9                  3.0
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop(labels='Petallength')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-b7f9db4a4d8d> in <module>
# ----> 1 iris.drop(labels='Petallength')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3829                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3830                 if errors == 'raise' and labels_missing:
# -> 3831                     raise KeyError('{} not found in axis'.format(labels))
#    3832
#    3833             slicer = [slice(None)] * self.ndim
#
# KeyError: "['Petallength'] not found in axis"

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
iris=iris.append(Series,ignore_index=True)

# %%
iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
# 150                   NaN                  NaN                   NaN
#
#      Petal width (in cm)  Sepal Length  Sepal Width
# 0                    0.2           NaN          NaN
# 1                    0.2           NaN          NaN
# 2                    0.2           NaN          NaN
# 3                    0.2           NaN          NaN
# 4                    0.2           NaN          NaN
# 5                    0.4           NaN          NaN
# 6                    0.3           NaN          NaN
# 7                    0.2           NaN          NaN
# 8                    0.2           NaN          NaN
# 9                    0.1           NaN          NaN
# 10                   0.2           NaN          NaN
# 11                   0.2           NaN          NaN
# 12                   0.1           NaN          NaN
# 13                   0.1           NaN          NaN
# 14                   0.2           NaN          NaN
# 15                   0.4           NaN          NaN
# 16                   0.4           NaN          NaN
# 17                   0.3           NaN          NaN
# 18                   0.3           NaN          NaN
# 19                   0.3           NaN          NaN
# 20                   0.2           NaN          NaN
# 21                   0.4           NaN          NaN
# 22                   0.2           NaN          NaN
# 23                   0.5           NaN          NaN
# 24                   0.2           NaN          NaN
# 25                   0.2           NaN          NaN
# 26                   0.4           NaN          NaN
# 27                   0.2           NaN          NaN
# 28                   0.2           NaN          NaN
# 29                   0.2           NaN          NaN
# ..                   ...           ...          ...
# 121                  2.0           NaN          NaN
# 122                  2.0           NaN          NaN
# 123                  1.8           NaN          NaN
# 124                  2.1           NaN          NaN
# 125                  1.8           NaN          NaN
# 126                  1.8           NaN          NaN
# 127                  1.8           NaN          NaN
# 128                  2.1           NaN          NaN
# 129                  1.6           NaN          NaN
# 130                  1.9           NaN          NaN
# 131                  2.0           NaN          NaN
# 132                  2.2           NaN          NaN
# 133                  1.5           NaN          NaN
# 134                  1.4           NaN          NaN
# 135                  2.3           NaN          NaN
# 136                  2.4           NaN          NaN
# 137                  1.8           NaN          NaN
# 138                  1.8           NaN          NaN
# 139                  2.1           NaN          NaN
# 140                  2.4           NaN          NaN
# 141                  2.3           NaN          NaN
# 142                  1.9           NaN          NaN
# 143                  2.3           NaN          NaN
# 144                  2.5           NaN          NaN
# 145                  2.3           NaN          NaN
# 146                  1.9           NaN          NaN
# 147                  2.0           NaN          NaN
# 148                  2.3           NaN          NaN
# 149                  1.8           NaN          NaN
# 150                  NaN           1.0          2.0
#
# [151 rows x 6 columns]

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR = np.genfromtxt(fname='HR_external.txt')
HR
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, 41., ...,  4.,  0.,  5.],
#        [nan, nan, 49., ...,  7.,  1.,  7.],
#        ...,
#        [nan, nan, 27., ...,  2.,  0.,  3.],
#        [nan, nan, 49., ...,  6.,  0.,  8.],
#        [nan, nan, 34., ...,  3.,  1.,  2.]])

# %%
HR = pd.read_csv('HR_external.txt')
HR
# Out:
#      Individual \tAttrition\tAge\tBusinessTravel\tDailyRate\tDepartment\tDistanceFromHome\tEducation\tEducationField\tEmployeeCount\tEmployeeNumber\tEnvironmentSatisfaction\tGender\tHourlyRate\tJobInvolvement\tJobLevel\tJobRole\tJobSatisfaction\tMaritalStatus\tMonthlyIncome\tMonthlyRate\tNumCompaniesWorked\tOverTime\tPercentSalaryHike\tPerformanceRating\tRelationshipSatisfaction\tStandardHours\tStockOptionLevel\tTotalWorkingYears\tTrainingTimesLastYear\tWorkLifeBalance\tYearsAtCompany\tYearsInCurrentRole\tYearsSinceLastPromotion\tYearsWithCurrManager
# 0     Ind1\tYes\t41\t1\t1102\t1\t1\t2\t1\t1\t1\t2\t2...
# 1     Ind2\tNo\t49\t2\t279\t2\t8\t1\t1\t1\t2\t3\t1\t...
# 2     Ind3\tYes\t37\t1\t1373\t2\t2\t2\t6\t1\t4\t4\t1...
# 3     Ind4\tNo\t33\t2\t1392\t2\t3\t4\t1\t1\t5\t4\t2\...
# 4     Ind5\tNo\t27\t1\t591\t2\t2\t1\t2\t1\t7\t1\t1\t...
# 5     Ind6\tNo\t32\t2\t1005\t2\t2\t2\t1\t1\t8\t4\t1\...
# 6     Ind7\tNo\t59\t1\t1324\t2\t3\t3\t2\t1\t10\t3\t2...
# 7     Ind8\tNo\t30\t1\t1358\t2\t24\t1\t1\t1\t11\t4\t...
# 8     Ind9\tNo\t38\t2\t216\t2\t23\t3\t1\t1\t12\t4\t1...
# 9     Ind10\tNo\t36\t1\t1299\t2\t27\t3\t2\t1\t13\t3\...
# 10    Ind11\tNo\t35\t1\t809\t2\t16\t3\t2\t1\t14\t1\t...
# 11    Ind12\tNo\t29\t1\t153\t2\t15\t2\t1\t1\t15\t4\t...
# 12    Ind13\tNo\t31\t1\t670\t2\t26\t1\t1\t1\t16\t1\t...
# 13    Ind14\tNo\t34\t1\t1346\t2\t19\t2\t2\t1\t18\t2\...
# 14    Ind15\tYes\t28\t1\t103\t2\t24\t3\t1\t1\t19\t3\...
# 15    Ind16\tNo\t29\t1\t1389\t2\t21\t4\t1\t1\t20\t2\...
# 16    Ind17\tNo\t32\t1\t334\t2\t5\t2\t1\t1\t21\t1\t1...
# 1459  Ind1460\tNo\t29\t1\t1378\t2\t13\t2\t6\t1\t2053...
# 1460  Ind1461\tNo\t29\t1\t468\t2\t28\t4\t2\t1\t2054\...
# 1461  Ind1462\tYes\t50\t1\t410\t1\t28\t3\t3\t1\t2055...
# 1462  Ind1463\tNo\t39\t1\t722\t1\t24\t1\t3\t1\t2056\...
# 1463  Ind1464\tNo\t31\t3\t325\t2\t5\t3\t2\t1\t2057\t...
# 1464  Ind1465\tNo\t26\t1\t1167\t1\t5\t3\t6\t1\t2060\...
# 1465  Ind1466\tNo\t36\t2\t884\t2\t23\t2\t2\t1\t2061\...
# 1466  Ind1467\tNo\t39\t1\t613\t2\t6\t1\t2\t1\t2062\t...
# 1467  Ind1468\tNo\t27\t1\t155\t2\t4\t3\t1\t1\t2064\t...
# 1468  Ind1469\tNo\t49\t2\t1023\t1\t2\t3\t2\t1\t2065\...
# 1469  Ind1470\tNo\t34\t1\t628\t2\t8\t3\t2\t1\t2068\t...
#
# [1470 rows x 1 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
Count_Row=HR.shape[0]
Count_Row
# Out:
# 1470

# %%
Count_Column=HR.shape[1]
Count_Column
# Out:
# 1

# %%
HR.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
HR.columns
# Out:
# Index(['Individual \tAttrition\tAge\tBusinessTravel\tDailyRate\tDepartment\tDistanceFromHome\tEducation\tEducationField\tEmployeeCount\tEmployeeNumber\tEnvironmentSatisfaction\tGender\tHourlyRate\tJobInvolvement\tJobLevel\tJobRole\tJobSatisfaction\tMaritalStatus\tMonthlyIncome\tMonthlyRate\tNumCompaniesWorked\tOverTime\tPercentSalaryHike\tPerformanceRating\tRelationshipSatisfaction\tStandardHours\tStockOptionLevel\tTotalWorkingYears\tTrainingTimesLastYear\tWorkLifeBalance\tYearsAtCompany\tYearsInCurrentRole\tYearsSinceLastPromotion\tYearsWithCurrManager'], dtype='object')

# %%
HR.lookup
# Out:
# <bound method DataFrame.lookup of      Individual \tAttrition\tAge\tBusinessTravel\tDailyRate\tDepartment\tDistanceFromHome\tEducation\tEducationField\tEmployeeCount\tEmployeeNumber\tEnvironmentSatisfaction\tGender\tHourlyRate\tJobInvolvement\tJobLevel\tJobRole\tJobSatisfaction\tMaritalStatus\tMonthlyIncome\tMonthlyRate\tNumCompaniesWorked\tOverTime\tPercentSalaryHike\tPerformanceRating\tRelationshipSatisfaction\tStandardHours\tStockOptionLevel\tTotalWorkingYears\tTrainingTimesLastYear\tWorkLifeBalance\tYearsAtCompany\tYearsInCurrentRole\tYearsSinceLastPromotion\tYearsWithCurrManager
# 0     Ind1\tYes\t41\t1\t1102\t1\t1\t2\t1\t1\t1\t2\t2...
# 1     Ind2\tNo\t49\t2\t279\t2\t8\t1\t1\t1\t2\t3\t1\t...
# 2     Ind3\tYes\t37\t1\t1373\t2\t2\t2\t6\t1\t4\t4\t1...
# 3     Ind4\tNo\t33\t2\t1392\t2\t3\t4\t1\t1\t5\t4\t2\...
# 1447  Ind1448\tNo\t36\t3\t301\t1\t15\t4\t3\t1\t2036\...
# 1448  Ind1449\tNo\t41\t1\t930\t1\t3\t3\t1\t1\t2037\t...
# 1449  Ind1450\tNo\t32\t1\t529\t2\t2\t3\t4\t1\t2038\t...
# 1450  Ind1451\tNo\t35\t1\t1146\t3\t26\t4\t1\t1\t2040...
# 1451  Ind1452\tNo\t38\t1\t345\t1\t10\t2\t1\t1\t2041\...
# 1452  Ind1453\tYes\t50\t2\t878\t1\t1\t4\t1\t1\t2044\...
# 1453  Ind1454\tNo\t36\t1\t1120\t1\t11\t4\t3\t1\t2045...
# 1454  Ind1455\tNo\t45\t1\t374\t1\t20\t3\t1\t1\t2046\...
# 1455  Ind1456\tNo\t40\t1\t1322\t2\t2\t4\t1\t1\t2048\...
# 1456  Ind1457\tNo\t35\t2\t1199\t2\t18\t4\t1\t1\t2049...
# 1457  Ind1458\tNo\t40\t1\t1194\t2\t2\t4\t2\t1\t2051\...
# 1458  Ind1459\tNo\t35\t1\t287\t2\t1\t4\t1\t1\t2052\t...
# 1459  Ind1460\tNo\t29\t1\t1378\t2\t13\t2\t6\t1\t2053...
# 1460  Ind1461\tNo\t29\t1\t468\t2\t28\t4\t2\t1\t2054\...
# 1461  Ind1462\tYes\t50\t1\t410\t1\t28\t3\t3\t1\t2055...
# 1462  Ind1463\tNo\t39\t1\t722\t1\t24\t1\t3\t1\t2056\...
# 1463  Ind1464\tNo\t31\t3\t325\t2\t5\t3\t2\t1\t2057\t...
# 1464  Ind1465\tNo\t26\t1\t1167\t1\t5\t3\t6\t1\t2060\...
# 1465  Ind1466\tNo\t36\t2\t884\t2\t23\t2\t2\t1\t2061\...
# 1466  Ind1467\tNo\t39\t1\t613\t2\t6\t1\t2\t1\t2062\t...
# 1467  Ind1468\tNo\t27\t1\t155\t2\t4\t3\t1\t1\t2064\t...
# 1468  Ind1469\tNo\t49\t2\t1023\t1\t2\t3\t2\t1\t2065\...
# 1469  Ind1470\tNo\t34\t1\t628\t2\t8\t3\t2\t1\t2068\t...
#
# [1470 rows x 1 columns]>

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
print(HR.dtypes)
# Out:
# Individual \tAttrition\tAge\tBusinessTravel\tDailyRate\tDepartment\tDistanceFromHome\tEducation\tEducationField\tEmployeeCount\tEmployeeNumber\tEnvironmentSatisfaction\tGender\tHourlyRate\tJobInvolvement\tJobLevel\tJobRole\tJobSatisfaction\tMaritalStatus\tMonthlyIncome\tMonthlyRate\tNumCompaniesWorked\tOverTime\tPercentSalaryHike\tPerformanceRating\tRelationshipSatisfaction\tStandardHours\tStockOptionLevel\tTotalWorkingYears\tTrainingTimesLastYear\tWorkLifeBalance\tYearsAtCompany\tYearsInCurrentRole\tYearsSinceLastPromotion\tYearsWithCurrManager    object
# dtype: object ()

# %%
for col in HR: print (HR[col].apply(type)) 0
# Out:
#   File "<ipython-input-172-35b43073848e>", line 1
#     for col in HR: print (HR[col].apply(type)) 0
#                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function
